# %%
from pandas import json_normalize
import pandas as pd
from pyairtable import Table
import streamlit as st

# %%
api_key = st.secrets['airtable_api_key']
base_id = st.secrets['base_id_key']
table_name = st.secrets['table_name_key']

# %%
table = Table(api_key, base_id, table_name)
data = table.all()
df = pd.json_normalize(data)

# %%
df = pd.json_normalize(data)

# %%
df
# Out:
#                     id               createdTime  \
# 0    rec01aVtgmHJsKPTP  2021-07-28T08:00:42.000Z
# 1    rec0JgVkRD460ZfYL  2021-06-04T03:28:50.000Z
# 2    rec0rag1Q8BRbijOQ  2021-07-07T08:53:34.000Z
# 3    rec0zbTKJnxXFacRQ  2021-08-12T07:31:21.000Z
# 4    rec10egVTjXj84F4s  2022-02-07T04:36:06.000Z
# ..                 ...                       ...
# 364  recyQXQvzTSWedi8y  2021-12-14T02:16:41.000Z
# 365  reczBcxa0WXOiiFbQ  2021-11-26T07:43:01.000Z
# 366  reczPqvyxjLLeODXR  2021-09-23T08:42:03.000Z
# 367  reczeGpdjDPFuMZfi  2021-06-02T12:11:30.000Z
# 368  reczs62jv43QlC0Et  2021-04-28T09:16:45.000Z
#
#                                     fields.Event Title  \
# 0    Panel Discussion: NAVIGATING GENDER EQUALITY I...
# 1                                            STEM Fair
# 2                   Virtual Robotics Camp - Afternoon
# 3    Opening ceremony: English course for journalis...
# 4                                                 PDEP
# ..                                                 ...
# 364                       HOLIDAY (Martin Luther King)
# 365  EdUSA-Promote EdUSA program and service at vir...
# 366  English Course for Journalists and Media Profe...
# 367                             Datacracy_Datatalk No1
# 368  EdUSA HCMC-Health Studies in the United States...
#
#             fields.Start Date  \
# 0    2021-09-21T16:30:00.000Z
# 1    2021-03-22T13:00:00.000Z
# 2    2021-07-07T13:30:00.000Z
# 3    2021-09-16T13:30:00.000Z
# 4    2022-03-31T14:00:00.000Z
# ..                        ...
# 364  2022-01-17T00:00:00.000Z
# 365  2021-11-26T15:30:00.000Z
# 366  2021-11-04T13:30:00.000Z
# 367  2021-04-08T17:00:00.000Z
# 368  2021-05-26T09:30:00.000Z
#
#                    fields.Agenda & Description & Blurb fields.Program Type  \
# 0    NAVIGATING GENDER EQUALITY IN PRESS & MEDIA \n...             Virtual
# 1    To celebrate Women’s History Month and to prom...              Onsite
# 2                                                  NaN             Virtual
# 3                                                  NaN             Virtual
# 4                                                  NaN              Onsite
# ..                                                 ...                 ...
# 364                                                NaN                 NaN
# 365                                                NaN             Virtual
# 366                                                NaN             Virtual
# 367                                                NaN              Onsite
# 368  Speaker: Dr. Ludmi Herath, Director, Internati...             Virtual
#
#                            fields.Room/Platform  \
# 0                 [PAS Gov Zoom, Facebook Live]
# 1                               [MPR, Football]
# 2                                [PAS Gov Zoom]
# 3                                           NaN
# 4                                         [Lab]
# ..                                          ...
# 364                                         NaN
# 365                                         NaN
# 366                                         NaN
# 367                                       [MPR]
# 368  [Edu Zoom, Facebook Live, Hanoi Crosspost]
#
#                                             fields.POC  fields.Participants  \
# 0    [{'id': 'usrsQTFjtlj6iCkI7', 'email': 'maida@f...                 88.0
# 1    [{'id': 'usriQCnYJMHwuIz5Q', 'email': 'trangh@...                200.0
# 2    [{'id': 'usrsQTFjtlj6iCkI7', 'email': 'maida@f...                 21.0
# 3    [{'id': 'usrwKFpxlAcJal8YC', 'email': 'phampm3...                  NaN
# 4    [{'id': 'usrwKFpxlAcJal8YC', 'email': 'phampm3...                  NaN
# ..                                                 ...                  ...
# 364                                                NaN                  NaN
# 365  [{'id': 'usrvlxGvrqFySfZZe', 'email': 'nguyent...                 60.0
# 366  [{'id': 'usrwKFpxlAcJal8YC', 'email': 'phampm3...                 22.0
# 367  [{'id': 'usrBqZS997UyMfuy7', 'email': 'vuml@am...                 40.0
# 368  [{'id': 'usrvlxGvrqFySfZZe', 'email': 'nguyent...                  NaN
#
#     fields.Mission Goals  ...  \
# 0    [recwTVxjpcKoEfX2u]  ...
# 1    [recwGLUbRoRe26qjY]  ...
# 2                    NaN  ...
# 3    [recwGLUbRoRe26qjY]  ...
# 4    [recmmHGNYSD6vgDpc]  ...
# ..                   ...  ...
# 364                  NaN  ...
# 365  [recwGLUbRoRe26qjY]  ...
# 366  [recwGLUbRoRe26qjY]  ...
# 367                  NaN  ...
# 368  [recwGLUbRoRe26qjY]  ...
#
#                              fields.Post-event Summary  \
# 0    Cultural Affairs Officer Monica Damberg-Ott de...
# 1                                                  NaN
# 2                                                  NaN
# 3    Information Officer Bintu Musa-Harry delivered...
# 4                                                  NaN
# ..                                                 ...
# 364                                                NaN
# 365  On November 26, EducationUSA Advisor Truc Nguy...
# 366                                                NaN
# 367                                                NaN
# 368  (U) EducationUSA HCMC hosted a May 26 virtual ...
#
#                               fields.Post-event Photos  \
# 0    [{'id': 'attR230bj6wG5YTpQ', 'width': 1747, 'h...
# 1                                                  NaN
# 2                                                  NaN
# 3    [{'id': 'attX60gconCCCNuxd', 'width': 1693, 'h...
# 4                                                  NaN
# ..                                                 ...
# 364                                                NaN
# 365  [{'id': 'attGIUeEigZDa24kN', 'width': 1059, 'h...
# 366  [{'id': 'att2h6rRyD4a0ITuo', 'width': 1639, 'h...
# 367                                                NaN
# 368  [{'id': 'attuX74P6bfDlVbnU', 'width': 384, 'he...
#
#                                fields.Post-event Title fields.Views  \
# 0    The U.S. Consulate General promotes gender equ...       [3830]
# 1                                                  NaN          NaN
# 2                                                  NaN          NaN
# 3    Launch of English Course for Journalists and M...          NaN
# 4                                                  NaN          NaN
# ..                                                 ...          ...
# 364                                                NaN          NaN
# 365  EducationUSA: Promote EducationUSA programs an...          NaN
# 366                                                NaN          NaN
# 367                                                NaN          NaN
# 368                Health Studies in the United States       [2239]
#
#     fields.Reach fields.Engagement  (from Engagement)  \
# 0         [8934]                                [677]
# 1            NaN                                  NaN
# 2            NaN                                  NaN
# 3            NaN                                  NaN
# 4            NaN                                  NaN
# ..           ...                                  ...
# 364          NaN                                  NaN
# 365          NaN                                  NaN
# 366          NaN                                  NaN
# 367          NaN                                  NaN
# 368       [8075]                                [266]
#
#     fields.Engagement Rate (from Facebook Metrics) fields.Notes  \
# 0                            [0.07577792702037162]          NaN
# 1                                              NaN          NaN
# 2                                              NaN          NaN
# 3                                              NaN          NaN
# 4                                              NaN          NaN
# ..                                             ...          ...
# 364                                            NaN          NaN
# 365                                            NaN          NaN
# 366                                            NaN          NaN
# 367                                            NaN          NaN
# 368                          [0.03294117647058824]    HCMC host
#
#     fields.Online viewers fields.SM Content Planning
# 0                     NaN                        NaN
# 1                     NaN                        NaN
# 2                     NaN                        NaN
# 3                     NaN                        NaN
# 4                     NaN                        NaN
# ..                    ...                        ...
# 364                   NaN                        NaN
# 365                  60.0                        NaN
# 366                   NaN                        NaN
# 367                   NaN                        NaN
# 368                  80.0        [recSM3N77OFnmDWXx]
#
# [369 rows x 25 columns]
